# %%
import json
import requests

# %%
res = requests.get("https://ergast.com/api/f1/2023.json")
res.json()

# %%
res = requests.get("https://ergast.com/api/f1/current.json")
res.json()

# %%
res = requests.get("http://ergast.com/api/f1/current/last/results.json")
res.json()

# endpoint for latest results 
# "http://ergast.com/api/f1/current/last/results"

# endpoint for historical data
# "http://ergast.com/api/f1/{year}/results.json"

# %%
# get all historical data, move to cloud
# then have a script that extracts only current/last/results to get latest results
# check if data exists within database already, perform upsert merge for incremental update
# how to get historical data without duplicating data with the get next?
# Out:
# <Response [200]>

# %%
from api import ergast_api

# %%
test = ergast_api.ErgastAPI()

# %%
test.base_url
# Out:
# 'http://ergast.com/api/f1'

# %%
test.get_latest_results()
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.5',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/current/last/results.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '20',
#   'RaceTable': {'season': '2023',
#    'round': '22',
#    'Races': [{'season': '2023',
#      'round': '22',
#      'url': 'https://en.wikipedia.org/wiki/2023_Abu_Dhabi_Grand_Prix',
#      'raceName': 'Abu Dhabi Grand Prix',
#      'Circuit': {'circuitId': 'yas_marina',
#       'url': 'http://en.wikipedia.org/wiki/Yas_Marina_Circuit',
#       'circuitName': 'Yas Marina Circuit',
#       'Location': {'lat': '24.4672',
#        'long': '54.6031',
#        'locality': 'Abu Dhabi',
#        'country': 'UAE'}},
#      'date': '2023-11-26',
#      'time': '13:00:00Z',
#      'Results': [{'number': '1',
#        'position': '1',
#        'positionText': '1',
#        'points': '26',
#        'Driver': {'driverId': 'max_verstappen',
#         'permanentNumber': '33',
#         'code': 'VER',
# ...

# %%
test.get_historical_results(2022, 2023)
# Out:
# [{'MRData': {'xmlns': 'http://ergast.com/mrd/1.5',
#    'series': 'f1',
#    'url': 'http://ergast.com/api/f1/2022.json',
#    'limit': '30',
#    'offset': '0',
#    'total': '22',
#    'RaceTable': {'season': '2022',
#     'Races': [{'season': '2022',
#       'round': '1',
#       'url': 'http://en.wikipedia.org/wiki/2022_Bahrain_Grand_Prix',
#       'raceName': 'Bahrain Grand Prix',
#       'Circuit': {'circuitId': 'bahrain',
#        'url': 'http://en.wikipedia.org/wiki/Bahrain_International_Circuit',
#        'circuitName': 'Bahrain International Circuit',
#        'Location': {'lat': '26.0325',
#         'long': '50.5106',
#         'locality': 'Sakhir',
#         'country': 'Bahrain'}},
#       'date': '2022-03-20',
#       'time': '15:00:00Z',
#       'FirstPractice': {'date': '2022-03-18', 'time': '12:00:00Z'},
#       'SecondPractice': {'date': '2022-03-18', 'time': '15:00:00Z'},
#       'ThirdPractice': {'date': '2022-03-19', 'time': '12:00:00Z'},
# ...
